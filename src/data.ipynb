# %%
from datasets import load_dataset

# Load the dataset
dataset = load_dataset("lmms-lab/AISG_Challenge")
# Out:
# README.md:   0%|          | 0.00/1.26k [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/94.1k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/1500 [00:00<?, ? examples/s]

# %%
import pandas as pd
test = dataset['test'].to_pandas()
test.shape
test.head(10)
# Out:
#       qid     video_id                                      question_type  \
# 0  0008-0  sj81PWrerDk                        Primary Open-ended Question
# 1  0008-1  sj81PWrerDk                    Paraphrased Open-ended Question
# 2  0008-2  sj81PWrerDk                  Correctly-led Open-ended Question
# 3  0008-3  sj81PWrerDk                    Wrongly-led Open-ended Question
# 4  0008-7  sj81PWrerDk  Multiple-choice Question with a Single Correct...
# 5  0012-0  AGCyLqLuUJ0                        Primary Open-ended Question
# 6  0012-1  AGCyLqLuUJ0                    Paraphrased Open-ended Question
# 7  0012-2  AGCyLqLuUJ0                  Correctly-led Open-ended Question
# 8  0012-3  AGCyLqLuUJ0                    Wrongly-led Open-ended Question
# 9  0012-7  AGCyLqLuUJ0  Multiple-choice Question with a Single Correct...
#
#                  capability  \
# 0  Plot Attribute (Montage)
# 1  Plot Attribute (Montage)
# 2  Plot Attribute (Montage)
# 3  Plot Attribute (Montage)
# 4  Plot Attribute (Montage)
# 5          Element Counting
# 6          Element Counting
# 7          Element Counting
# 8          Element Counting
# 9          Element Counting
#
#                                             question duration  \
# 0  What is the difference between the action of t...     8.85
# 1  Can you describe how the actions of the last p...     8.85
# 2  Did the last person open the bottle without us...     8.85
# 3  Did the last person in the video open the bott...     8.85
# 4  How does the last person in the video open the...     8.85
# 5        How many robot figures appear in the video?    20.67
# 6  What is the total number of robot figures show...    20.67
# 7  Does the video display four robot figures in t...    20.67
# 8  Are there only two robot figures shown in the ...    20.67
# 9  How many robot figures are shown in the video?...    20.67
#
#                                      question_prompt answer  \
# 0  Please state your answer with a brief explanat...
# 1  Please state your answer with a brief explanat...
# 2  Please state your answer with a brief explanat...
# 3  Please state your answer with a brief explanat...
# 4  E. None of the above\nSelect one best answer t...
# 5  Please state your answer with a brief explanat...
# 6  Please state your answer with a brief explanat...
# 7  Please state your answer with a brief explanat...
# 8  Please state your answer with a brief explanat...
# 9  E. None of the above\nSelect one best answer t...
#
#                                   youtube_url
# 0  https://www.youtube.com/shorts/sj81PWrerDk
# 1  https://www.youtube.com/shorts/sj81PWrerDk
# 2  https://www.youtube.com/shorts/sj81PWrerDk
# 3  https://www.youtube.com/shorts/sj81PWrerDk
# 4  https://www.youtube.com/shorts/sj81PWrerDk
# 5  https://www.youtube.com/shorts/AGCyLqLuUJ0
# 6  https://www.youtube.com/shorts/AGCyLqLuUJ0
# 7  https://www.youtube.com/shorts/AGCyLqLuUJ0
# 8  https://www.youtube.com/shorts/AGCyLqLuUJ0
# 9  https://www.youtube.com/shorts/AGCyLqLuUJ0
